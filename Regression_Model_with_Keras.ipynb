# %% [markdown]
# # Predictions of Concrete

# %% [markdown]
# The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:
#
# 1. Cement
#
# 2. Blast Furnace Slag
#
# 3. Fly Ash
#
# 4. Water
#
# 5. Superplasticizer
#
# 6. Coarse Aggregate
#
# 7. Fine Aggregate

# %%
import pandas as pd
import numpy as np
# !pip install tensorflow==2.13.0
# !pip install keras==2.1.6
# Out:
# ...
#   Obtaining dependency information for tensorflow==2.13.0 from https://files.pythonhosted.org/packages/d6/69/d461fa09235326e08b7ca463d5491426fdd4908ef6d3f9ed51d0777dc071/tensorflow-2.13.0-cp311-cp311-macosx_12_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for tensorflow-macos==2.13.0 from https://files.pythonhosted.org/packages/f1/cc/6c262ae6f3a23b118b1104fa5f6126067744ffa9226faade202b0a20bdd3/tensorflow_macos-2.13.0-cp311-cp311-macosx_12_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for absl-py>=1.0.0 from https://files.pythonhosted.org/packages/a2/ad/e0d3c824784ff121c03cc031f944bc7e139a8f1870ffd2845cc2dd76f6c4/absl_py-2.1.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for flatbuffers>=23.1.21 from https://files.pythonhosted.org/packages/6f/12/d5c79ee252793ffe845d58a913197bfa02ae9a0b5c9bc3dc4b58d477b9e7/flatbuffers-23.5.26-py2.py3-none-any.whl.metadata
# ...

# %% [markdown]
# ## Prepare the data

# %%
#read the data as pandas dataframe
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
# count the amount of rows and columns
concrete_data.shape
# Out:
# (1030, 9)

# %%
# see the statistics of the data
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %%
# see if there's any missing data
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
# split the data into predictors and targets
concrete_data_columns = concrete_data.columns
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']]
target = concrete_data[concrete_data_columns[concrete_data_columns == 'Strength']]

# %%
# check if the predictors are corect
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
# check if the targets are corect
target.head()
# Out:
#    Strength
# 0     79.99
# 1     61.89
# 2     40.27
# 3     41.05
# 4     44.30

# %%
# normalize the predictors by subtracting by the mean and dividing by the standards diviation
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %%
# to build the model, the number of predictors will hae to be specified in numbers and saved
n_cols = predictors_norm.shape[1]

# %% [markdown]
# ## Building the regression model

# %%
import keras
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 import keras
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/__init__.py:3
#       1 from __future__ import absolute_import
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/utils/__init__.py:25
#      23 from .np_utils import to_categorical
#      24 from .np_utils import normalize
# ---> 25 from .multi_gpu_utils import multi_gpu_model
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/utils/multi_gpu_utils.py:7
#       4 from __future__ import division
#       5 from __future__ import print_function
# ----> 7 from ..layers.merge import concatenate
#       8 from .. import backend as K
#       9 from ..layers.core import Lambda
#
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 from keras.models import Sequential
#       2 from keras.layers import Dense
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/__init__.py:3
#       1 from __future__ import absolute_import
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/utils/__init__.py:25
#      23 from .np_utils import to_categorical
#      24 from .np_utils import normalize
# ---> 25 from .multi_gpu_utils import multi_gpu_model
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/utils/multi_gpu_utils.py:7
#       4 from __future__ import division
#       5 from __future__ import print_function
# ----> 7 from ..layers.merge import concatenate
#       8 from .. import backend as K
# ...

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# train and test the model
# build the model
model = regression_model()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 # train and test the model
#       2 # build the model
# ----> 3 model = regression_model()
#
# Cell In[33], line 4, in regression_model()
#       2 def regression_model():
#       3     # create model
# ----> 4     model = Sequential()
#       5     model.add(Dense(50, activation='relu', input_shape=(n_cols,)))
#       6     model.add(Dense(50, activation='relu'))
#
# NameError: name 'Sequential' is not defined

# %%
# fit the model
model.fit(predictors_norm, target, validation_split = 0.3, epochs = 100, verbose = 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 # fit the model
# ----> 2 model.fit(predictors_norm, target, validation_split = 0.3, epochs = 100, verbose = 2)
#
# NameError: name 'model' is not defined
